# %% [markdown]
# # Sanity check - Nutrition, physical activity and obesity
# ---

# %% [markdown]
# ## 0. Configuração do ambiente

# %%
# bibliotecas

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# base de dados

data = pd.read_csv('../nutrition_physical_activity_and_obesity/Nutrition__Physical_Activity__and_Obesity.csv')

# %%
data.shape
# Out:
# (88629, 33)

# %%
data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc
# 0       2020     2020           US     National  \
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class
# 0  Behavioral Risk Factor Surveillance System        Physical Activity  \
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic
# 0  Physical Activity - Behavior  \
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
# ...

# %%
data['LocationDesc'].value_counts()
# Out:
# LocationDesc
# National                1652
# West Virginia           1652
# Oklahoma                1652
# Mississippi             1652
# Oregon                  1652
# Wisconsin               1652
# Kansas                  1652
# Florida                 1652
# Idaho                   1652
# Arizona                 1652
# Montana                 1652
# Georgia                 1652
# North Carolina          1652
# Pennsylvania            1652
# North Dakota            1652
# South Carolina          1652
# Nebraska                1652
# Tennessee               1652
# Missouri                1652
# Nevada                  1652
# Iowa                    1652
# Indiana                 1652
# Ohio                    1652
# Alaska                  1652
# Vermont                 1652
# Colorado                1652
# Kentucky                1652
# Utah                    1652
# New York                1652
# Wyoming                 1652
# District of Columbia    1652
# ...
